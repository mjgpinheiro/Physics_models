# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Physics_models/blob/Econophysics/Crypto_Binance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-binance
# !pip install ta

import pandas as pd
import ta
import time
from binance.client import Client
from binance.enums import *

# Set up Binance client
api_key = 'your_api_key'
api_secret = 'your_api_secret'
client = Client(api_key, api_secret, tld='us')

# Set up trading parameters
symbol = 'ETHUSDT'
trade_qty = 0.01 # trade quantity in ETH
fee = 0.00075 # Binance trading fee

# Set up indicator parameters
ema1_period = 28
ema2_period = 48
stoch_rsi_period = 14

# Retrieve historical data
klines = client.get_historical_klines(symbol, Client.KLINE_INTERVAL_1HOUR, "1 day ago UTC")
df = pd.DataFrame(klines, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume', 'close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'])
df.drop(columns=['close_time', 'quote_asset_volume', 'number_of_trades', 'taker_buy_base_asset_volume', 'taker_buy_quote_asset_volume', 'ignore'], inplace=True)
df.set_index('timestamp', inplace=True)
df.index = pd.to_datetime(df.index, unit='ms')
df = df.apply(pd.to_numeric)
df['close'] = df['close'].astype(float)

# Create indicators
df['ema1'] = ta.trend.ema_indicator(df['close'], window=ema1_period)
df['ema2'] = ta.trend.ema_indicator(df['close'], window=ema2_period)
df['stoch_rsi'] = ta.momentum.stochrsi(df['close'], window=stoch_rsi_period)

# Set up trading variables
usdt_balance = float(client.get_asset_balance(asset='USDT')['free'])
eth_balance = float(client.get_asset_balance(asset='ETH')['free'])
usdt_trade_size = trade_qty * df.iloc[-1]['close'] # use current close price for trade size
eth_trade_size = trade_qty

# Trading loop
while True:
    # Get current price and indicators
    current_price = float(client.get_symbol_ticker(symbol=symbol)['price'])
    current_ema1 = df['ema1'].iloc[-1]
    current_ema2 = df['ema2'].iloc[-1]
    current_stoch_rsi = df['stoch_rsi'].iloc[-1]
    
    # Buy signal
    if current_ema1 > current_ema2 and current_stoch_rsi < 0.8 and usdt_balance > usdt_trade_size:
        order = client.order_market_buy(symbol=symbol, quantity=eth_trade_size)
        usdt_balance = float(client.get_asset_balance(asset='USDT')['free'])
        eth_balance = float(client.get_asset_balance(asset='ETH')['free'])
        print(f'Bought {eth_trade_size} ETH at {current_price} USDT')
    
    # Sell signal
    elif current_ema1 < current_ema2 and current_stoch_rsi > 0.2 and eth_balance > eth_trade_size:
        order = client.order_market_sell(symbol=symbol, quantity=eth_trade_size)
        usdt_balance = float(client.get_asset_balance(asset='USDT')['free'])
        eth_balance = float(client.get_asset_balance(asset='ETH')['balance'])
usdt_balance = float(client.get_asset_balance(asset='USDT')['balance'])
print(f"ETH balance: {eth_balance}")
print(f"USDT balance: {usdt_balance}")

# Calculate the current market price of ETHUSDT
depth = client.get_order_book(symbol='ETHUSDT')
bid_price = float(depth['bids'][0][0])
ask_price = float(depth['asks'][0][0])
market_price = (bid_price + ask_price) / 2

# Check if the current market price is higher than the last closing price
last_close = dfTest['close'][-1]
if market_price > last_close:
# Buy ETH with all USDT balance
  eth_quantity = usdt_balance / market_price
  print(f"Buying {eth_quantity} ETH at {market_price} USDT per ETH")
  order = client.order_market_buy(symbol='ETHUSDT', quantity=eth_quantity)
  print(order)
elif market_price < last_close:
# Sell all ETH balance for USDT
  print(f"Selling {eth_balance} ETH at {market_price} USDT per ETH")
  order = client.order_market_sell(symbol='ETHUSDT', quantity=eth_balance)
  print(order)
else:
  print("Market price is the same as the last closing price, no action taken.")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 KB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 KB 22.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 66.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.5/129.5 KB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 KB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 264.6/264.6 KB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 KB 12.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 KB 20.3 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
