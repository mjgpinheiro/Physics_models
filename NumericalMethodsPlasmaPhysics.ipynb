# %% [markdown]
# <a href="https://colab.research.google.com/github/mjgpinheiro/Physics_models/blob/main/NumericalMethodsPlasmaPhysics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
L = 1.0  # Length of the domain
Nx = 100  # Number of points in the domain
x = np.linspace(0, L, Nx)  # Spatial grid
dx = x[1] - x[0]  # Grid spacing
n0 = 1.0  # Initial density
v = 0.1  # Drift velocity
dt = 0.005  # Time step
t_end = 0.5  # Final time

# Gaussian pulse as initial condition
n_initial = n0 + 0.5*np.exp(-100*(x-0.3)**2)

# Initializing
n_fd = np.copy(n_initial)
n_fv = np.copy(n_initial)
n_fe = np.copy(n_initial)
n_sp = np.copy(n_initial)

# Finite Difference Method
for t in np.arange(0, t_end, dt):
    n_fd[1:-1] -= v * dt/dx * (n_fd[2:] - n_fd[1:-1])

# ... [Rest of your code remains unchanged] ...
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
L = 10.0  # Length of the domain
nx = 100  # Number of grid points
dx = L/nx  # Grid spacing
dt = 0.01  # Time step
v = 1.0  # Particle velocity
t_end = 0.5  # End time

# Initial condition: Gaussian profile for density
x = np.linspace(0, L, nx)
n0 = np.exp(-((x - L/4)**2) / 2)
n_fd = np.copy(n0)
n_fv = np.copy(n0)

# FD method
for t in np.arange(0, t_end, dt):
    n_fd[:-1] = n_fd[:-1] - v*dt/dx * (n_fd[1:] - n_fd[:-1])

# FV method
for t in np.arange(0, t_end, dt):
    flux = v * 0.5 * (n_fv[1:] + n_fv[:-1])
    n_fv[1:-1] += (flux[:-1] - flux[1:]) * dt/dx

# Plot results
plt.figure(figsize=(10, 6))
plt.plot(x, n0, label="Initial")
plt.plot(x, n_fd, label="Finite Difference")
plt.plot(x, n_fv, label="Finite Volume")
plt.legend()
plt.title("Evolution of Plasma Plume Density")
plt.xlabel("x")
plt.ylabel("Density, n")
plt.show()
# Plot results
plt.figure(figsize=(10, 6))
plt.plot(x, n_fd, label='Finite Difference')
plt.plot(x, n_fv, label='Finite Volume')
plt.plot(x, n_fe, label='Finite Element')
plt.plot(x, n_sp, label='Spectral')
plt.legend()
plt.xlabel('x')
plt.ylabel('n')
plt.title('Comparison of Numerical Methods')
plt.show()
